# %%
import os
import time
from datetime import datetime
from tqdm.notebook import trange
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor
import cv2
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class ImageLoader:
    
    def __init__(self, folders_path, data_type, height=480, width=640, channel_first=False, file_mask=None, postprocessing=None):
        
        self.channels = 3
        self.height = height
        self.width = width
        self.data_type = data_type
        self.postprocessing = postprocessing
        self.file_mask = file_mask
        
        self.file_names = []
        for folder in folders_path:
            self.file_names += self._find_files(folder)
            
        self.file_names.sort()
        
        self.count = len(self.file_names)
            
        self.channel_first = channel_first
        
        if self.channel_first:
            self.images = np.zeros((self.count, self.channels, self.height, self.width), dtype=np.uint8)
        else:
            self.images = np.zeros((self.count, self.height, self.width, self.channels), dtype=np.uint8)
            
        ptr = 0
        for file_name in self.file_names:
            print('Loading image :', file_name)
            self.images[ptr] = self._load_image(file_name)
            ptr += 1
            
    def _find_files(self, path):
        files = []
        for (dirpath, dirnames, filenames) in os.walk(path):
            files.append(filenames)
            
        result = []
        for file_name in files[0]:
            if file_name.endswith('.jpg') or file_name.endswith('.png'):
                if self.file_mask == None:
                    result.append(path+file_name)
                elif file_name.find(self.file_mask) != -1:
                    result.append(path+file_name)
                    
        return result
    
    def _load_image(self, file_name):
        image = Image.open(file_name).convert('RGB')
        
        if self.data_type == 'mask':
            image = image.crop((0, 1, 640, 479))
        else:
            image = image.resize((640, 478))
            
        if self.postprocessing is not None:
            image = self.postprocessing(image)
            image_np = np.array(image)
        else:
            image = image.resize((self.width, self.height))
            image_np = np.array(image)
            if self.channel_first and len(image_np.shape) > 2:
                image_np = np.moveaxis(image_np, 2, 0)
        
        return image_np

# %%
class DatasetProcess:
    
    def __init__(self, folders_training, folders_testing, classes_ids, height=480, width=640, augmentation_count=10):
        
        self.classes_ids = classes_ids
        self.classes_count = len(classes_ids)
        self.height = height
        self.width = width
        self.channels = 3
        
        self.training_images = []
        self.training_masks  = []
        self.training_count  = 0
        
        for folder in folders_training:
            images = ImageLoader([folder + '/images/'], 'image', height, width, channel_first=True)
            masks  = ImageLoader([folder + '/mask/'], 'mask', height, width, channel_first=True, file_mask='_watershed_mask', postprocessing=self._mask_postprocessing)
            
        self.training_images.append(images.images)
        self.training_masks.append(masks.images)
        
        print('Processing augmentations\n')
        
        images_aug, masks_aug = self._augmentation(images.images, masks.images, augmentation_count)
        
        self.training_images.append(images_aug)
        self.training_masks.append(masks_aug)
        
        self.training_count += images.count * (1 + augmentation_count)
        
        self.testing_images = []
        self.testing_masks = []
        self.testing_count = 0
        
        for folder in folders_testing:
            images = ImageLoader([folder + "/images/"], height, width, channel_first=True)
            masks = ImageLoader([folder + "/mask/"], height, width, channel_first=True, file_mask="_watershed_mask",
                                 postprocessing=None)
            self.testing_images.append(images.images)
            self.testing_masks.append(masks.images)
            self.testing_count += images.count
        
        self.input_shape = (self.channels, self.height, self.width)
        self.output_shape = (self.classes_count, self.height, self.width)
        print("\n\n\n\n")
        print("dataset summary : \n")
        print("training_count = ", self.get_training_count())
        print("testing_count  = ", self.get_testing_count())
        print("channels = ", self.channels)
        print("height   = ", self.height)
        print("width    = ", self.width)
        print("classes_count =  ", self.classes_count)
        print("\n")
    
    def get_training_count(self):
        return self.training_count
    
    def get_testing_count(self):
        return self.testing_count
    def get_training_batch(self, batch_size=32):
        return self._get_batch(self.training_images, self.training_masks, batch_size, augmentation=True)
    
    def get_testing_batch(self, batch_size=32):
        return self._get_batch(self.training_images, self.training_masks, batch_size, augmentation=False)
    
    def process(self, images, masks, augmentation=True):
        group_idx = np.random.randint(len(images))
        image_idx = np.random.randint(len(images[group_idx]))
        image_np = np.array(images[group_idx][image_idx]) / 256.0
        mask_np = np.array(masks[group_idx][image_idx]).mean(axis=0).astype(int)
        #if self._rnd(0, 1) > 0.1:
        if augmentation:
            image_np = self._augmentation_noise(image_np)
            image_np, mask_np = self._augmentation_flip(image_np, mask_np)
        mask_one_hot = np.eye(self.classes_count)[mask_np]
        mask_one_hot = np.moveaxis(mask_one_hot, 2, 0)
        result_x = torch.from_numpy(image_np).float()
        result_y = torch.from_numpy(mask_one_hot).float()
        return result_x, result_y
    
    def _get_batch(self, images, masks, batch_size, augmentation=True):
        result_x = torch.zeros((batch_size, self.channels, self.height, self.width)).float()
        result_y = torch.zeros((batch_size, self.classes_count, self.height, self.width)).float()
        with ThreadPoolExecutor(max_workers=batch_size) as executor:
            results = [None] * batch_size
            for x in range(batch_size):
                results[x] = executor.submit(self.process, images, masks,  augmentation=augmentation)
            counter = 0
            for f in concurrent.futures.as_completed(results):
                result_x[counter], result_y[counter] = f.result()[0], f.result()[1]
                counter += 1
        return result_x, result_y
    def _augmentation(self, images, masks, augmentation_count):
        angle_max, crop_prop = 25, 0.2
        count = images.shape[0]
        total_count = count * augmentation_count
        images_result = np.zeros((total_count, images.shape[1], images.shape[2], images.shape[3]), dtype=np.uint8)
        mask_result = np.zeros((total_count, masks.shape[1], masks.shape[2], masks.shape[3]), dtype=np.uint8)
        ptr = 0
        for j in range(count):
            image_in = Image.fromarray(np.moveaxis(images[j], 0, 2), 'RGB')
            mask_in = Image.fromarray(np.moveaxis(masks[j], 0, 2), 'RGB')
            for i in range(augmentation_count):
                angle = self._rnd(-angle_max, angle_max)
                image_aug = image_in.rotate(angle)
                mask_aug = mask_in.rotate(angle)
                c_left = int(self._rnd(0, crop_prop) * self.width)
                c_top = int(self._rnd(0, crop_prop) * self.height)
                c_right = int(self._rnd(1.0 - crop_prop, 1.0) * self.width)
                c_bottom = int(self._rnd(1.0 - crop_prop, 1.0) * self.height)
                image_aug = image_aug.crop((c_left, c_top, c_right, c_bottom))
                mask_aug = mask_aug.crop((c_left, c_top, c_right, c_bottom))
                if np.random.rand() < 0.5:
                    fil = np.random.randint(6)
                    if fil == 0:
                        image_aug = image_aug.filter(ImageFilter.BLUR)
                    elif fil == 1:
                        image_aug = image_aug.filter(ImageFilter.EDGE_ENHANCE)
                    elif fil == 2:
                        image_aug = image_aug.filter(ImageFilter.EDGE_ENHANCE_MORE)
                    elif fil == 3:
                        image_aug = image_aug.filter(ImageFilter.SHARPEN)
                    elif fil == 4:
                        image_aug = image_aug.filter(ImageFilter.SMOOTH)
                    elif fil == 5:
                        image_aug = image_aug.filter(ImageFilter.SMOOTH_MORE)
                image_aug = image_aug.resize((self.width, self.height))
                mask_aug = mask_aug.resize((self.width, self.height))
                image_aug = np.array(image_aug)
                mask_aug = np.array(mask_aug)
                image_aug = np.moveaxis(image_aug, 2, 0)
                mask_aug = np.moveaxis(mask_aug, 2, 0)
                images_result[ptr] = image_aug
                mask_result[ptr] = mask_aug
                ptr += 1
        return images_result, mask_result
    def _augmentation_noise(self, image_np):
        brightness = self._rnd(-0.25, 0.25)
        contrast = self._rnd(0.5, 1.5)
        noise = 0.05 * (2.0 * np.random.rand(self.channels, self.height, self.width) - 1.0)
        result = image_np + brightness
        result = 0.5 + contrast * (result - 0.5)
        result = result + noise
        return np.clip(result, 0.0, 1.0)
    def _augmentation_flip(self, image_np, mask_np):
        # random flips?
        if self._rnd(0,1) < 0.5:
            image_np = np.flip(image_np , 2)
            mask_np = np.flip(mask_np, 1)
        return image_np.copy(),mask_np.copy()
    def _rnd(self, min_value, max_value):
        return (max_value - min_value) * np.random.rand() + min_value
    def _mask_postprocessing(self, image):
        image = image.resize((self.width, self.height), Image.NEAREST)
        image = image.convert("L")
        for i in range(len(self.classes_ids)):
            image.putpixel((4 * i + self.width // 2, 4 * i + self.height // 2), self.classes_ids[i])
        return image.quantize(self.classes_count)

# %%
class CustomModel(nn.Module):
    
    def __init__(self, input_shape=(3, 256, 352), output_shape=(2, 256, 352)):
        super(CustomModel, self).__init__()
        
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        self.layers_encoder_0 = [
            self.conv_bn(input_shape[0], 32, 2),
            self.conv_bn(32, 64, 1),
            self.conv_bn(64, 128, 2),
            self.conv_bn(128, 128, 1),
            self.conv_bn(128, 128, 1),
            self.conv_bn(128, 128, 1),
            self.conv_bn(128, 256, 2),            
            
        ]
        
        self.layers_encoder_1 = [
            self.conv_bn(256, 256, 1),
            self.conv_bn(256, 512, 2),
            self.conv_bn(512, 512, 1),
            self.conv_bn(512, 512, 1),
            self.conv_bn(512, 512, 1),
            self.conv_bn(512, 512, 1),
            self.conv_bn(512, 512, 2)
        ]
        
        self.layers_decoder = [
            self.conv_bn(512+256, 256, 1),
            self.conv_bn(256, 256, 1),
            self.conv_bn(256, 128, 1),
            self.conv_bn(128, 128, 1),
            self.conv_bn(128, 128, 1),
            
            nn.Conv2d(128, output_shape[0], kernel_size=1, stride=1, padding=0),
            nn.Upsample(scale_factor=8, mode='bilinear', align_corners=False)
        ]
        
        for i in range(len(self.layers_encoder_0)):
            if hasattr(self.layers_encoder_0[i], 'weight'):
                nn.init.xavier_uniform_(self.layers_encoder_0[i].weight)
                nn.init.zeros_(self.layers_encoder_0[i].bias)
                
        for i in range(len(self.layers_encoder_1)):
            if hasattr(self.layers_encoder_1[i], 'weight'):
                nn.init.xavier_uniform_(self.layers_encoder_1[i].weight)
                nn.init.zeros_(self.layers_encoder_1[i].bias)
                
        for i in range(len(self.layers_decoder)):
            if hasattr(self.layers_decoder[i], 'weight'):
                nn.init.xavier_uniform_(self.layers_decoder[i].weight)
                nn.init.zeros_(self.layers_decoder[i].bias)
                
        self.model_encoder_0 = nn.Sequential(*self.layers_encoder_0)
        self.model_encoder_0.to(self.device)
        
        self.model_encoder_1 = nn.Sequential(*self.layers_encoder_1)
        self.model_encoder_1.to(self.device)
        
        self.model_decoder = nn.Sequential(*self.layers_decoder)
        self.model_decoder.to(self.device)
        
        print(self.model_encoder_0)
        print(self.model_encoder_1)
        print(self.model_decoder)
        
        
    def forward(self, x):
        encoder_0 = self.model_encoder_0(x)
        encoder_1 = self.model_encoder_1(encoder_0)
        
        encoder_1_up = F.interpolate(encoder_1, scale_factor=4, mode='nearest')
        
        d_in = torch.cat([encoder_0, encoder_1_up], dim=1)
        
        y = self.model_decoder(d_in)
        
        return y
    
    def conv_bn(self, inputs, outputs, stride):
        return nn.Sequential(
            nn.Conv2d(inputs, outputs, kernel_size=3, stride=stride, padding=1),
            nn.BatchNorm2d(outputs),
            nn.LeakyReLU(inplace=True))

# %%
# Load training images from folders
folders_training = []
folders_training.append('City_dataset_full/City_sunny1/')
folders_training.append('City_dataset_full/City_sunny2/')
folders_training.append('City_dataset_full/City_rainy1/')
folders_training.append('City_dataset_full/City_rainy2/')
folders_training.append('City_dataset_full/City_2/')
# Assign classes 
classes_ids = [8, 12]
classes_count = len(classes_ids)
# Load the model
model = CustomModel()
# Time estimating variables
epochminus, arrayloss, arrayepoch, lossforavg = 0, [], [], 0
# Number of epoches
N_EPOCHS = 100
# Batch size
BATCH_SIZE = 128
# Load images (height and width must be divisible by 32)
dataset = DatasetProcess(folders_training, folders_training, classes_ids, height=384, width=512, augmentation_count=25)
MAXLOSS = 9999.0
# Print start time()
print(time.time())
for epoch in trange(N_EPOCHS):
    # Time estimating variables
    epochminus += 1
    timestart = time.time()
    
    # Calculate batch_count 
    batch_count = (dataset.get_training_count() + BATCH_SIZE) // BATCH_SIZE
    print(batch_count, 'BATCH_COUNT')
    
    # Set optimizer for the model parameters
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
    
    # Print current epoch
    print('EPOCH - ', epoch)
    
    # Batch loop
    for batch in trange(batch_count):
        # Get batch from model loader
        x, y = dataset.get_training_batch(BATCH_SIZE)
        
        # Put images on DEVICE
        x = x.to(model.device)
        y = y.to(model.device)
        
        # Push images to model
        y_pred = model.forward(x)
        
        # Calculate loss for optimizer
        loss = ((y - y_pred) ** 2).mean()
        
        # Get loss number for graph
        lossforavg += float(loss.data.cpu().numpy())
        
        # Save best model
        if epoch > 10 and MAXLOSS > float(loss.data.cpu().numpy()):
            torch.save(model.state_dict(), 'best_model.pt')
            MAXLOSS = float(loss.data.cpu().numpy())
            print('Best model saved')
            
        # Reset, find and update gradients
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    # Graphing variables
    arrayepoch.append(epoch)
    arrayloss.append(lossforavg / batch_count)
    print(lossforavg / batch_count, 'Epoch avg loss')
    lossforavg = 0
    
    # Time estimating variables
    timetoend = (N_EPOCHS - epochminus) * (time.time() - timestart)
    dt_object = datetime.fromtimestamp(timetoend + time.time())
    print(dt_object, 'time to end')
    # Save final model
    PATH = './Model_final.pt'
    torch.save(model.state_dict(), PATH)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (1): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (3): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (4): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (5): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (6): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
# )
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (1): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (2): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (3): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (4): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (5): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (6): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
# )
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (1): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (2): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (3): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (4): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (5): Conv2d(128, 2, kernel_size=(1, 1), stride=(1, 1))
#   (6): Upsample(scale_factor=8.0, mode='bilinear')
# )
# Loading image : City_dataset_full/City_sunny1//images/20210303_103546.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103547.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103548.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103549(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103549.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103550.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103551.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103552.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103553.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103555.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103557.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103558.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103601.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103605.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103606.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103610.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103611.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103613.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103617.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103619.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103621.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103622.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103626.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103627.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103629.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103631.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103633.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103635.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103636.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103640.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103643.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103644.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103646.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103648.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103649.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103651.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103652.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103654.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103656.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103659.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103701.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103703.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103705.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103706.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103707.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103710.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103711.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103714.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103715.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103716.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103717.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103719.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103721.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103722.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103723.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103724.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103726.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103727.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103728.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103729.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103730.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103731.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103732.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103734(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103734.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103735.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103737.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103738.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103739.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103740.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103741.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103743.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103744.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103745.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103746.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103748.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103752.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103753.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103754.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103755.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103757.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103758.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103759.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103800.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103801.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103802.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103804.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103805.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103806.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103807.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103808.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103809.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103810.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103811.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103812.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103813.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103815.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103816.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103817.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103819.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103820.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103823.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103824.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103826.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103828.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103830.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103831.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103832.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103833.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103834.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103836.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103837.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103838.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103839.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103840.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103841.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103842.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103843.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103846.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103847.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103848.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103849.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103850.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103851.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103853.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103855.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103858.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103902.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103903.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103905.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103908.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103910.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103911.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103912.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103913.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103914.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103916.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103917(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103917.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103918.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103920.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103922.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103923.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103924.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103925.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103926.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103927.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103928(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103928.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103930.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103932.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103933(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103933.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103934.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103941.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103942.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103948.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_103957.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104004.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104016.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104021.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104034.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104036.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104037.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104038.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104043.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104044.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104048.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104049(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104049.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104050.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104051.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104052(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104052.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104053.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104054.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104055.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104058.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104059.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104100.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104101.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104110.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104116.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104118.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104124.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104128.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104131.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104133.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104134.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104135.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104139.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104145.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104147.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104149.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104150(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104150.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104151.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104152.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104153.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104154.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104156.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104158.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104159.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104200.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104202.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210303_104224.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145630.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145642.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145652.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145702.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145717.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145734.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145835(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145835.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145840.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145855(0).jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145855.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145858.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145900.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145912.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145915.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145920.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145931.jpg
# Loading image : City_dataset_full/City_sunny1//images/20210307_145938.jpg
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103546_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103547_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103548_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103549(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103549_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103550_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103551_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103552_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103553_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103555_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103557_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103558_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103601_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103605_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103606_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103610_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103611_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103613_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103617_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103619_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103621_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103622_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103626_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103627_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103629_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103631_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103633_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103635_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103636_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103640_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103643_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103644_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103646_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103648_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103649_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103651_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103652_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103654_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103656_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103659_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103701_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103703_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103705_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103706_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103707_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103710_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103711_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103714_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103715_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103716_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103717_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103719_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103721_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103722_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103723_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103724_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103726_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103727_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103728_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103729_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103730_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103731_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103732_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103734(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103734_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103735_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103737_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103738_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103739_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103740_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103741_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103743_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103744_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103745_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103746_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103748_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103752_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103753_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103754_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103755_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103757_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103758_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103759_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103800_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103801_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103802_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103804_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103805_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103806_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103807_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103808_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103809_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103810_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103811_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103812_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103813_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103815_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103816_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103817_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103819_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103820_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103823_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103824_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103826_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103828_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103830_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103831_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103832_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103833_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103834_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103836_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103837_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103838_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103839_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103840_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103841_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103842_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103843_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103846_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103847_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103848_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103849_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103850_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103851_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103853_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103855_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103858_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103902_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103903_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103905_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103908_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103910_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103911_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103912_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103913_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103914_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103916_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103917(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103917_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103918_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103920_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103922_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103923_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103924_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103925_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103926_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103927_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103928(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103928_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103930_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103932_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103933(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103933_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103934_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103941_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103942_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103948_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_103957_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104004_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104016_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104021_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104034_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104036_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104037_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104038_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104043_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104044_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104048_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104049(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104049_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104050_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104051_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104052(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104052_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104053_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104054_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104055_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104058_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104059_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104100_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104101_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104110_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104116_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104118_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104124_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104128_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104131_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104133_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104134_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104135_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104139_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104145_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104147_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104149_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104150(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104150_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104151_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104152_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104153_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104154_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104156_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104158_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104159_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104200_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104202_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210303_104224_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145630_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145642_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145652_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145702_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145717_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145734_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145835(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145835_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145840_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145855(0)_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145855_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145858_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145900_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145912_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145915_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145920_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145931_watershed_mask.png
# Loading image : City_dataset_full/City_sunny1//mask/20210307_145938_watershed_mask.png
# Loading image : City_dataset_full/City_sunny2//images/20210306_160742.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160746.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160748.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160751.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160757.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160758.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160805.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160807.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160810.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160811.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160813.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160815.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160817.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160819.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160820.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160830.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160834.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160840.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160845.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160852.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160900.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160905.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160913.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160921.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160923.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160932.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160953.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_160957.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161005.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161008.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161011.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161013.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161018.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161029.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161032.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161035.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161038.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161044.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161052.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161100.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161104.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161109.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161111.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161125.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161128.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161138.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161143.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161153.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161155.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161159.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161202.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161212.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161216.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161219.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161225.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161227.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161229.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161233.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161235.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161237.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161241.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161243.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161244.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161250.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161252.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161256.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161258.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161300.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161302.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161305.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161307.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161310.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161313.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161318.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161320.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161327.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161331.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161333.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161336.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161339.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161342.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161345.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161351.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161355.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161400.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161402.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161404.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161408.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161412.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161417.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161419.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161420.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161426.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161427.jpg
# Loading image : City_dataset_full/City_sunny2//images/20210306_161428.jpg
# ...
# Loading image : City_dataset_full/City_2//mask/20201217_083556_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083600_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083609_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083613_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083617_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083618_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083627_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083632_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083705_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083708_watershed_mask.png
# Loading image : City_dataset_full/City_2//mask/20201217_083710_watershed_mask.png
#
#
#
#
#
# dataset summary :
#
# training_count =  5382
# testing_count  =  1213
# channels =  3
# height   =  384
# width    =  512
# classes_count =   2
#
#
# 1735243438.258726
#   0%|          | 0/100 [00:00<?, ?it/s]
# 43 BATCH_COUNT
# EPOCH -  0
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.16535969728300737 Epoch avg loss
# 2024-12-30 16:10:58.019244 time to end
# 43 BATCH_COUNT
# EPOCH -  1
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.06377023653408816 Epoch avg loss
# 2024-12-31 03:14:12.780246 time to end
# 43 BATCH_COUNT
# EPOCH -  2
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.033055045230444086 Epoch avg loss
# 2024-12-31 05:08:17.824726 time to end
# 43 BATCH_COUNT
# EPOCH -  3
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.022838846931970396 Epoch avg loss
# 2024-12-31 02:34:31.070968 time to end
# 43 BATCH_COUNT
# EPOCH -  4
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.018333732605327006 Epoch avg loss
# 2025-01-01 18:30:16.498172 time to end
# 43 BATCH_COUNT
# EPOCH -  5
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.016736538495955078 Epoch avg loss
# 2024-12-31 12:27:44.869239 time to end
# 43 BATCH_COUNT
# EPOCH -  6
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.013315098316863526 Epoch avg loss
# 2024-12-31 09:40:59.113923 time to end
# 43 BATCH_COUNT
# EPOCH -  7
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.01240011720463287 Epoch avg loss
# 2024-12-30 21:29:04.830315 time to end
# 43 BATCH_COUNT
# EPOCH -  8
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.011439658376539862 Epoch avg loss
# 2024-12-30 20:34:07.507785 time to end
# 43 BATCH_COUNT
# EPOCH -  9
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.010195151328780624 Epoch avg loss
# 2024-12-31 03:46:12.167024 time to end
# 43 BATCH_COUNT
# EPOCH -  10
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.009891257946227873 Epoch avg loss
# 2024-12-31 18:05:01.395587 time to end
# 43 BATCH_COUNT
# EPOCH -  11
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# Best model saved
# 0.009124056425292132 Epoch avg loss
# 2024-12-31 04:58:18.365159 time to end
# 43 BATCH_COUNT
# EPOCH -  12
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# 0.008859758157023164 Epoch avg loss
# 2024-12-31 03:42:44.028515 time to end
# 43 BATCH_COUNT
# EPOCH -  13
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.008340863251062326 Epoch avg loss
# 2025-01-01 14:05:13.414794 time to end
# 43 BATCH_COUNT
# EPOCH -  14
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.00777504634285389 Epoch avg loss
# 2025-01-02 16:25:44.194504 time to end
# 43 BATCH_COUNT
# EPOCH -  15
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.008026221463846605 Epoch avg loss
# 2024-12-31 14:59:29.565948 time to end
# 43 BATCH_COUNT
# EPOCH -  16
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.006910459333380988 Epoch avg loss
# 2024-12-31 13:05:38.632010 time to end
# 43 BATCH_COUNT
# EPOCH -  17
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.006932360661584277 Epoch avg loss
# 2024-12-31 13:25:22.027599 time to end
# 43 BATCH_COUNT
# EPOCH -  18
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0067047994193989175 Epoch avg loss
# 2025-01-01 07:37:38.644582 time to end
# 43 BATCH_COUNT
# EPOCH -  19
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.006501995915070523 Epoch avg loss
# 2024-12-31 12:46:37.259878 time to end
# 43 BATCH_COUNT
# EPOCH -  20
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.00636595547155932 Epoch avg loss
# 2024-12-31 01:51:02.947245 time to end
# 43 BATCH_COUNT
# EPOCH -  21
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.006069117041607929 Epoch avg loss
# 2024-12-31 02:31:18.861017 time to end
# 43 BATCH_COUNT
# EPOCH -  22
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# Best model saved
# 0.005740703105233436 Epoch avg loss
# 2024-12-31 08:20:28.223698 time to end
# 43 BATCH_COUNT
# EPOCH -  23
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.005862014021637828 Epoch avg loss
# 2024-12-31 11:02:22.278276 time to end
# 43 BATCH_COUNT
# EPOCH -  24
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.005987111500702625 Epoch avg loss
# 2024-12-31 10:13:03.599020 time to end
# 43 BATCH_COUNT
# EPOCH -  25
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.005556593248404042 Epoch avg loss
# 2024-12-31 08:18:08.862628 time to end
# 43 BATCH_COUNT
# EPOCH -  26
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.005635706588712542 Epoch avg loss
# 2024-12-31 12:53:15.839298 time to end
# 43 BATCH_COUNT
# EPOCH -  27
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.00556748200121314 Epoch avg loss
# 2025-01-02 00:21:43.796633 time to end
# 43 BATCH_COUNT
# EPOCH -  28
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# 0.005308515348926533 Epoch avg loss
# 2024-12-31 13:51:20.867902 time to end
# 43 BATCH_COUNT
# EPOCH -  29
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# 0.005194785885599463 Epoch avg loss
# 2024-12-31 16:27:53.920616 time to end
# 43 BATCH_COUNT
# EPOCH -  30
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.005008600717193858 Epoch avg loss
# 2025-01-04 16:44:47.420169 time to end
# 43 BATCH_COUNT
# EPOCH -  31
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# Best model saved
# 0.0048530572418903194 Epoch avg loss
# 2024-12-31 09:24:43.451249 time to end
# 43 BATCH_COUNT
# EPOCH -  32
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0048011833325374955 Epoch avg loss
# 2024-12-31 07:31:25.851085 time to end
# 43 BATCH_COUNT
# EPOCH -  33
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004773681496031756 Epoch avg loss
# 2025-01-01 10:39:45.731075 time to end
# 43 BATCH_COUNT
# EPOCH -  34
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.004778830496984166 Epoch avg loss
# 2024-12-31 16:30:11.283367 time to end
# 43 BATCH_COUNT
# EPOCH -  35
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.004944603337884643 Epoch avg loss
# 2024-12-31 17:01:51.782750 time to end
# 43 BATCH_COUNT
# EPOCH -  36
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.0045901618215666955 Epoch avg loss
# 2024-12-31 15:05:40.921511 time to end
# 43 BATCH_COUNT
# EPOCH -  37
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004450647398656191 Epoch avg loss
# 2024-12-31 14:33:38.583330 time to end
# 43 BATCH_COUNT
# EPOCH -  38
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004643476643967767 Epoch avg loss
# 2024-12-31 10:44:25.252817 time to end
# 43 BATCH_COUNT
# EPOCH -  39
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# 0.004333830449383619 Epoch avg loss
# 2024-12-31 08:29:00.864678 time to end
# 43 BATCH_COUNT
# EPOCH -  40
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0042792584660441375 Epoch avg loss
# 2024-12-31 10:38:19.649766 time to end
# 43 BATCH_COUNT
# EPOCH -  41
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004205002833894173 Epoch avg loss
# 2024-12-31 12:46:14.124672 time to end
# 43 BATCH_COUNT
# EPOCH -  42
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004243162422722509 Epoch avg loss
# 2025-01-03 01:01:26.938028 time to end
# 43 BATCH_COUNT
# EPOCH -  43
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004219211675876448 Epoch avg loss
# 2025-01-02 15:09:14.527475 time to end
# 43 BATCH_COUNT
# EPOCH -  44
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004069574577950461 Epoch avg loss
# 2024-12-31 13:24:00.918657 time to end
# 43 BATCH_COUNT
# EPOCH -  45
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0041164407008435835 Epoch avg loss
# 2024-12-31 11:32:48.377795 time to end
# 43 BATCH_COUNT
# EPOCH -  46
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004027013796879802 Epoch avg loss
# 2024-12-31 17:47:52.993738 time to end
# 43 BATCH_COUNT
# EPOCH -  47
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004027096847028926 Epoch avg loss
# 2025-01-01 02:28:21.281677 time to end
# 43 BATCH_COUNT
# EPOCH -  48
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# 0.003910169644324586 Epoch avg loss
# 2024-12-31 19:50:10.668183 time to end
# 43 BATCH_COUNT
# EPOCH -  49
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.0040032415661614305 Epoch avg loss
# 2024-12-31 09:22:29.655169 time to end
# 43 BATCH_COUNT
# EPOCH -  50
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003992230268628444 Epoch avg loss
# 2024-12-31 12:56:57.485188 time to end
# 43 BATCH_COUNT
# EPOCH -  51
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003929252433049125 Epoch avg loss
# 2025-01-02 04:58:15.651377 time to end
# 43 BATCH_COUNT
# EPOCH -  52
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.004028796770631574 Epoch avg loss
# 2025-01-02 23:38:32.849190 time to end
# 43 BATCH_COUNT
# EPOCH -  53
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003921331745723999 Epoch avg loss
# 2024-12-31 14:01:51.302265 time to end
# 43 BATCH_COUNT
# EPOCH -  54
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.0039455010014217955 Epoch avg loss
# 2024-12-31 13:01:51.177584 time to end
# 43 BATCH_COUNT
# EPOCH -  55
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.0037687843568016623 Epoch avg loss
# 2025-01-01 06:45:30.383298 time to end
# 43 BATCH_COUNT
# EPOCH -  56
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003860771899696353 Epoch avg loss
# 2025-01-02 04:22:48.259336 time to end
# 43 BATCH_COUNT
# EPOCH -  57
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003966573934438963 Epoch avg loss
# 2025-01-02 04:59:55.345856 time to end
# 43 BATCH_COUNT
# EPOCH -  58
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0037975584286763227 Epoch avg loss
# 2024-12-31 14:37:59.060289 time to end
# 43 BATCH_COUNT
# EPOCH -  59
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0038386533405025338 Epoch avg loss
# 2024-12-31 17:25:39.375381 time to end
# 43 BATCH_COUNT
# EPOCH -  60
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0037903581843386556 Epoch avg loss
# 2024-12-31 17:58:38.314231 time to end
# 43 BATCH_COUNT
# EPOCH -  61
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0037556664834102224 Epoch avg loss
# 2025-01-01 16:02:41.186646 time to end
# 43 BATCH_COUNT
# EPOCH -  62
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003786631188420362 Epoch avg loss
# 2025-01-01 22:02:14.280179 time to end
# 43 BATCH_COUNT
# EPOCH -  63
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.00370448422185037 Epoch avg loss
# 2025-01-01 00:41:53.103712 time to end
# 43 BATCH_COUNT
# EPOCH -  64
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.0036079237064303355 Epoch avg loss
# 2024-12-31 18:40:42.814731 time to end
# 43 BATCH_COUNT
# EPOCH -  65
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0037017219136793946 Epoch avg loss
# 2024-12-31 19:21:14.616530 time to end
# 43 BATCH_COUNT
# EPOCH -  66
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.003567971516573845 Epoch avg loss
# 2024-12-31 18:34:51.990757 time to end
# 43 BATCH_COUNT
# EPOCH -  67
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0036484855876932312 Epoch avg loss
# 2025-01-03 05:00:26.782420 time to end
# 43 BATCH_COUNT
# EPOCH -  68
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003612694817833429 Epoch avg loss
# 2025-01-02 11:11:40.891545 time to end
# 43 BATCH_COUNT
# EPOCH -  69
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.003548161061697228 Epoch avg loss
# 2025-01-02 10:29:54.756181 time to end
# 43 BATCH_COUNT
# EPOCH -  70
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003653252302387426 Epoch avg loss
# 2024-12-31 20:52:11.310292 time to end
# 43 BATCH_COUNT
# EPOCH -  71
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003526908535033811 Epoch avg loss
# 2025-01-01 03:01:28.858374 time to end
# 43 BATCH_COUNT
# EPOCH -  72
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0035225872957515853 Epoch avg loss
# 2025-01-01 02:06:04.460731 time to end
# 43 BATCH_COUNT
# EPOCH -  73
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# Best model saved
# 0.0035090611294605013 Epoch avg loss
# 2025-01-01 00:23:16.768075 time to end
# 43 BATCH_COUNT
# EPOCH -  74
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0034542250511951224 Epoch avg loss
# 2025-01-01 01:59:27.629827 time to end
# 43 BATCH_COUNT
# EPOCH -  75
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0034770404237734025 Epoch avg loss
# 2025-01-01 03:39:33.812124 time to end
# 43 BATCH_COUNT
# EPOCH -  76
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.0034735969072857567 Epoch avg loss
# 2024-12-31 23:25:00.017943 time to end
# 43 BATCH_COUNT
# EPOCH -  77
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0034289593689230294 Epoch avg loss
# 2024-12-31 23:53:14.068674 time to end
# 43 BATCH_COUNT
# EPOCH -  78
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0034214676206195077 Epoch avg loss
# 2024-12-31 23:18:24.127213 time to end
# 43 BATCH_COUNT
# EPOCH -  79
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# Best model saved
# 0.003399494650968632 Epoch avg loss
# 2025-01-01 05:43:47.917000 time to end
# 43 BATCH_COUNT
# EPOCH -  80
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0033790011576181928 Epoch avg loss
# 2025-01-01 11:48:23.108090 time to end
# 43 BATCH_COUNT
# EPOCH -  81
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0034448299123797307 Epoch avg loss
# 2025-01-01 04:26:27.264875 time to end
# 43 BATCH_COUNT
# EPOCH -  82
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003442851425863283 Epoch avg loss
# 2025-01-01 00:20:20.399795 time to end
# 43 BATCH_COUNT
# EPOCH -  83
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003395319006644016 Epoch avg loss
# 2025-01-01 00:21:45.819806 time to end
# 43 BATCH_COUNT
# EPOCH -  84
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003378593644430471 Epoch avg loss
# 2024-12-31 23:49:06.242830 time to end
# 43 BATCH_COUNT
# EPOCH -  85
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003412647118661986 Epoch avg loss
# 2025-01-02 08:24:41.965207 time to end
# 43 BATCH_COUNT
# EPOCH -  86
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0033449840699430813 Epoch avg loss
# 2025-01-01 18:06:19.766312 time to end
# 43 BATCH_COUNT
# EPOCH -  87
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0033501946681374034 Epoch avg loss
# 2025-01-01 17:22:13.641952 time to end
# 43 BATCH_COUNT
# EPOCH -  88
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0033396194569853157 Epoch avg loss
# 2025-01-01 04:14:29.853033 time to end
# 43 BATCH_COUNT
# EPOCH -  89
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003345038812217671 Epoch avg loss
# 2025-01-01 04:14:57.019714 time to end
# 43 BATCH_COUNT
# EPOCH -  90
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.0032938027992671314 Epoch avg loss
# 2025-01-01 04:29:45.318473 time to end
# 43 BATCH_COUNT
# EPOCH -  91
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0032514839779672236 Epoch avg loss
# 2025-01-01 04:33:20.847098 time to end
# 43 BATCH_COUNT
# EPOCH -  92
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0032641080608808025 Epoch avg loss
# 2025-01-01 08:29:09.682528 time to end
# 43 BATCH_COUNT
# EPOCH -  93
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0032800105129650167 Epoch avg loss
# 2025-01-01 05:21:36.779025 time to end
# 43 BATCH_COUNT
# EPOCH -  94
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003279456354374456 Epoch avg loss
# 2025-01-01 05:32:28.988031 time to end
# 43 BATCH_COUNT
# EPOCH -  95
#   0%|          | 0/43 [00:00<?, ?it/s]
# Best model saved
# 0.003282782199337732 Epoch avg loss
# 2025-01-01 05:22:51.090856 time to end
# 43 BATCH_COUNT
# EPOCH -  96
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0033347116577503986 Epoch avg loss
# 2025-01-01 05:30:54.192466 time to end
# 43 BATCH_COUNT
# EPOCH -  97
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0032281908369081657 Epoch avg loss
# 2025-01-01 05:25:34.578168 time to end
# 43 BATCH_COUNT
# EPOCH -  98
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.003281128251665207 Epoch avg loss
# 2025-01-01 12:32:40.474620 time to end
# 43 BATCH_COUNT
# EPOCH -  99
#   0%|          | 0/43 [00:00<?, ?it/s]
# 0.0032320212637789027 Epoch avg loss
# 2025-01-01 09:40:04.182584 time to end

# %%
class Inference:
    
    def __init__(self, classes_count):
        
        # Load model
        self.model = CustomModel()
        self.device = self.model.device
        # Path to trained weights
        self.PATH = 'best_model.pt'
        # Load weights
        self.model.load_state_dict(torch.load(self.PATH))
        # Set GPU device if available
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        # Turn on evaluation mode
        self.model.eval()
        self.colors = self._make_colors(classes_count)
        
        print('Segmentation Inference ready')
        
    def process(self, image_np, channel_first=False, alpha=0.35):
        
        # Put image to device
        image_t= torch.from_numpy(image_np).float().to(self.device)
        image_t = image_t / 256.0
        
        if channel_first == False:
            image_in_t = image_t.transpose(0, 2).transpose(1, 2)
        else:
            image_in_t = image_t
            
        # Process image
        prediction_t = self.model(image_in_t.unsqueeze(0)).squeeze(0)
        prediction_t = torch.argmax(prediction_t, dim=0)
        prediction_t = prediction_t.transpose(0, 1)
        
        mask_t = self.colors[prediction_t, :].transpose(0, 1)
        
        # Mix mask with image with alpha 0.35
        result_t = (1.0 - alpha) * image_t + alpha * mask_t
        
        # Get results back to CPU
        prediction = prediction_t.detach().to('cpu').numpy()
        mask = mask_t.detach().to('cpu').numpy()
        result = result_t.detach().to('cpu').numpy()
        
        return prediction, mask, result
        
    # Make colors for mask
    def _make_colors(self, count):
        
        result = []
        
        result.append([0, 0, 0])
        result.append([0, 0, 1])
        result.append([0, 0, 0])
        result.append([0, 0, 0])
        result.append([0, 0, 0])
        
        result = torch.from_numpy(np.array(result)).to(self.device)
        
        return result

# %%
# Load desired video
cap = cv2.VideoCapture('driving.mp4')
show_video = False
save_video = True
# Set same height and width as trained model have
height = 480
widht = 640
# Load segmentation inference
si = Inference(2)
if save_video:
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter('output1.mp4', fourcc, 25.0, (widht, height))
    
fps_smooth = 0.0
frame_skip = 20
next_frame = 0
cnt = 0
def print_video(image, text):
    x = cv2.putText(image, text, (20, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1, lineType=cv2.LINE_AA)
    
while(True):
    ret, frame = cap.read()
    
    if ret == False:
        break
        
    frame = cv2.resize(frame, (widht, height), interpolation=cv2.INTER_AREA)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    if cnt > next_frame:
        time_start = time.time()
        
        # Sent frame to inference model and get result
        prediction_np, mask, result = si.process(frame)
        
        # Count FPS
        time_stop = time.time()
        fps = 1.0 / (time_stop - time_start)
        result = (result * 255).astype(np.uint8)
        
        # Print FPS
        text = 'fps = ' + str(round(fps, 1))
        
        im_bgr = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
        print_video(im_bgr, text)
        
        if show_video:
            cv2.imshow('frame', im_bgr)
            
        if save_video:
            writer.write(im_bgr)
            
        frame_skip = 1
        # frame_skip = int(np.clip(frame_skip, 1, 500))
        
        next_frame = cnt + frame_skip
        
    cnt += 1
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (1): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (3): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (4): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (5): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (6): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
# )
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (1): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (2): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (3): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (4): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (5): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (6): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
# )
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (1): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (2): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (3): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (4): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (5): Conv2d(128, 2, kernel_size=(1, 1), stride=(1, 1))
#   (6): Upsample(scale_factor=8.0, mode='bilinear')
# )
# Segmentation Inference ready
